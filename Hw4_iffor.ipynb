# %%
# Logical Processing Homework

# Problem 1 Stacking logical operators

# influenza_genome = 
# [19, 15, 7, 9, 12, 6, 17, 20, 29, 14, 22, 8, 15, 12, 21, 25, 11, 10, 30, 4, 6, 24, 18, 21, 28, 22, 13, 19, 4, 23, 16, 25, 13, 28, 16, 29, 4, 3, 25, 13, 10, 26, 26, 18, 25, 28, 24, 18, 3, 9, 11, 29, 30, 16, 24, 5, 5, 25, 14, 7, 1, 15, 6, 6, 19, 19, 15, 2, 14, 7, 21, 5, 26, 25, 18, 18, 9, 7, 27, 4, 1, 23, 30, 25, 24, 29, 11, 16, 20, 15, 2, 9, 8, 13, 1, 13, 5, 17, 29, 25, 16, 13, 3, 30, 10, 21, 9, 18, 20, 14, 20, 19, 6, 4, 20, 5, 14, 5, 12, 27, 18, 28, 13, 30, 6, 9, 12, 9, 29, 4, 14, 22, 7, 25, 11, 12, 5, 24, 6, 3, 8, 3, 20, 24, 8, 23, 22, 11, 22, 10, 13, 14, 2, 6, 22, 22, 7, 6, 18, 28, 25, 4, 6, 24, 10, 24, 15, 18, 12, 24, 10, 16, 24, 21, 19, 24, 8, 8, 8, 10, 8, 15, 26, 14, 21, 18, 6, 10, 23, 2, 20, 15, 1, 4, 20, 8, 6, 1, 4, 15, 21, 26, 25, 1, 24, 15, 27, 8, 23, 4, 30, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 30, 16, 30, 10, 2, 26, 26, 7, 10, 15, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 30, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 7, 26, 11, 25, 1, 23, 9, 12, 2, 4, 17, 27, 9, 13, 19, 15, 10, 12, 21, 25, 5, 1, 16, 17, 28, 23, 18, 10, 15, 18, 1, 11, 14, 10, 18, 12, 1, 23, 23, 25, 13, 27, 27, 6, 9, 11, 23, 6, 23, 14, 9, 15, 11, 24, 11, 29, 18, 6, 19, 16, 14, 26, 2, 14, 15, 25, 6, 21, 23, 25, 27, 5, 1, 17, 4, 7, 18, 8, 9, 10, 5, 21, 29, 9, 6, 2, 22, 12, 1, 13, 19, 6, 17, 21, 22, 26, 21, 10, 29, 8, 13, 10, 29, 6, 29, 16, 30, 5, 25, 14, 15, 15, 9, 24, 13, 5, 28, 18, 11, 21, 15, 12, 5, 16, 5, 29, 29, 29, 3, 10, 24, 16, 16, 12, 14, 6, 22, 21, 10, 10, 2, 14, 9, 29, 29, 2, 26, 11, 6, 7, 28, 10, 3, 24, 30, 2, 23, 9, 29, 27, 19, 1, 15, 11, 5, 7, 9, 26, 28, 27, 10, 20, 23, 29, 10, 15, 30, 13, 2, 11, 5, 9, 2, 30, 27, 14, 11, 20, 19, 1, 12, 10, 8, 6, 16, 3, 25, 5, 10, 24]

# Given the array influenza_genome, write code that uses for loops and if statements to do the following and print the results(see below for instructions):

# 1.1 add 1 to the value at the index 300.

# 1.2 for the first 30 elements, if the value of the element is divisable by 3, multiply the value by 3.

# 1.3 for the last 30 elements, if the index value at that point is divisable by 5, replace the value with "a".

# 1.4 for all elements between index 200 and 300, if the value of the element is divisable by BOTH 3 AND 5, replace the value with the 10.

# Only print the section of the array that is modified after completing each operation. i.e only print index 300 of the array after 1.1 and only the first 30 elements after 1.2





# Problem 2 Loops within loops
# Given the array influenza_genome, write code using both for and while loops that:

# 2.1 Create a for loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)

# 2.2 Create a while loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)

# 2.3 Create a for loop that iterates over items index 234 through 237 and if the index is 236 print the item 7 times.




# Problem 3 Functions
# You are going to implement 3 funtions that will process the influenza_genome list in various ways.

# 3.1 write a function, that takes in the array as an argument, and outputs 10 values from the dataset, spaced out by indexes that are 25 apart (ie 0, 25, 50, etc)

# 3.2 write a function that takes in the dataset as an argument and outputs 20 values from the dataset, spaced out by indexes that are y apart (ie you can decide how far apart they should be iterated as long as they dont exceed the length of the dataset)

# 3.3 write a function that takes the output from the function from 3.2 as an argument, then only prints out every other item (ie there should only be 10 outputs)




# Problem 4 Putting it all together
# Write a function that implements the code from problem 1.4, then implements the code from problem 2.3.

# The function should create a modified version of the influenza_genome list as per 1.4, then print the section described in problem 2.3.

# %%
# Problem 1 Stacking logical operators

# influenza_genome = 
# [19, 15, 7, 9, 12, 6, 17, 20, 29, 14, 22, 8, 15, 12, 21, 25, 11, 10, 30, 4, 6, 24, 18, 21, 28, 22, 13, 19, 4, 23, 16, 25, 13, 28, 16, 29, 4, 3, 25, 13, 10, 26, 26, 18, 25, 28, 24, 18, 3, 9, 11, 29, 30, 16, 24, 5, 5, 25, 14, 7, 1, 15, 6, 6, 19, 19, 15, 2, 14, 7, 21, 5, 26, 25, 18, 18, 9, 7, 27, 4, 1, 23, 30, 25, 24, 29, 11, 16, 20, 15, 2, 9, 8, 13, 1, 13, 5, 17, 29, 25, 16, 13, 3, 30, 10, 21, 9, 18, 20, 14, 20, 19, 6, 4, 20, 5, 14, 5, 12, 27, 18, 28, 13, 30, 6, 9, 12, 9, 29, 4, 14, 22, 7, 25, 11, 12, 5, 24, 6, 3, 8, 3, 20, 24, 8, 23, 22, 11, 22, 10, 13, 14, 2, 6, 22, 22, 7, 6, 18, 28, 25, 4, 6, 24, 10, 24, 15, 18, 12, 24, 10, 16, 24, 21, 19, 24, 8, 8, 8, 10, 8, 15, 26, 14, 21, 18, 6, 10, 23, 2, 20, 15, 1, 4, 20, 8, 6, 1, 4, 15, 21, 26, 25, 1, 24, 15, 27, 8, 23, 4, 30, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 30, 16, 30, 10, 2, 26, 26, 7, 10, 15, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 30, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 7, 26, 11, 25, 1, 23, 9, 12, 2, 4, 17, 27, 9, 13, 19, 15, 10, 12, 21, 25, 5, 1, 16, 17, 28, 23, 18, 10, 15, 18, 1, 11, 14, 10, 18, 12, 1, 23, 23, 25, 13, 27, 27, 6, 9, 11, 23, 6, 23, 14, 9, 15, 11, 24, 11, 29, 18, 6, 19, 16, 14, 26, 2, 14, 15, 25, 6, 21, 23, 25, 27, 5, 1, 17, 4, 7, 18, 8, 9, 10, 5, 21, 29, 9, 6, 2, 22, 12, 1, 13, 19, 6, 17, 21, 22, 26, 21, 10, 29, 8, 13, 10, 29, 6, 29, 16, 30, 5, 25, 14, 15, 15, 9, 24, 13, 5, 28, 18, 11, 21, 15, 12, 5, 16, 5, 29, 29, 29, 3, 10, 24, 16, 16, 12, 14, 6, 22, 21, 10, 10, 2, 14, 9, 29, 29, 2, 26, 11, 6, 7, 28, 10, 3, 24, 30, 2, 23, 9, 29, 27, 19, 1, 15, 11, 5, 7, 9, 26, 28, 27, 10, 20, 23, 29, 10, 15, 30, 13, 2, 11, 5, 9, 2, 30, 27, 14, 11, 20, 19, 1, 12, 10, 8, 6, 16, 3, 25, 5, 10, 24]

# Given the array influenza_genome, write code that uses for loops and if statements to do the following and print the results(see below for instructions):

# 1.1 add 1 to the value at the index 300.

# 1.2 for the first 30 elements, if the value of the element is divisable by 3, multiply the value by 3.

# 1.3 for the last 30 elements, if the index value at that point is divisable by 5, replace the value with "a".

# 1.4 for all elements between index 200 and 300, if the value of the element is divisable by BOTH 3 AND 5, replace the value with the 10.

# Only print the section of the array that is modified after completing each operation. i.e only print index 300 of the array after 1.1 and only the first 30 elements after 1.2

##########################

#1.1 add 1 to the value at the index 300.
influenza_genome = [19, 15, 7, 9, 12, 6, 17, 20, 29, 14, 22, 8, 15, 12, 21, 25, 11, 10, 30, 4, 6, 24, 18, 21, 28, 22, 13, 19, 4, 23, 16, 25, 13, 28, 16, 29, 4, 3, 25, 13, 10, 26, 26, 18, 25, 28, 24, 18, 3, 9, 11, 29, 30, 16, 24, 5, 5, 25, 14, 7, 1, 15, 6, 6, 19, 19, 15, 2, 14, 7, 21, 5, 26, 25, 18, 18, 9, 7, 27, 4, 1, 23, 30, 25, 24, 29, 11, 16, 20, 15, 2, 9, 8, 13, 1, 13, 5, 17, 29, 25, 16, 13, 3, 30, 10, 21, 9, 18, 20, 14, 20, 19, 6, 4, 20, 5, 14, 5, 12, 27, 18, 28, 13, 30, 6, 9, 12, 9, 29, 4, 14, 22, 7, 25, 11, 12, 5, 24, 6, 3, 8, 3, 20, 24, 8, 23, 22, 11, 22, 10, 13, 14, 2, 6, 22, 22, 7, 6, 18, 28, 25, 4, 6, 24, 10, 24, 15, 18, 12, 24, 10, 16, 24, 21, 19, 24, 8, 8, 8, 10, 8, 15, 26, 14, 21, 18, 6, 10, 23, 2, 20, 15, 1, 4, 20, 8, 6, 1, 4, 15, 21, 26, 25, 1, 24, 15, 27, 8, 23, 4, 30, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 30, 16, 30, 10, 2, 26, 26, 7, 10, 15, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 30, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 7, 26, 11, 25, 1, 23, 9, 12, 2, 4, 17, 27, 9, 13, 19, 15, 10, 12, 21, 25, 5, 1, 16, 17, 28, 23, 18, 10, 15, 18, 1, 11, 14, 10, 18, 12, 1, 23, 23, 25, 13, 27, 27, 6, 9, 11, 23, 6, 23, 14, 9, 15, 11, 24, 11, 29, 18, 6, 19, 16, 14, 26, 2, 14, 15, 25, 6, 21, 23, 25, 27, 5, 1, 17, 4, 7, 18, 8, 9, 10, 5, 21, 29, 9, 6, 2, 22, 12, 1, 13, 19, 6, 17, 21, 22, 26, 21, 10, 29, 8, 13, 10, 29, 6, 29, 16, 30, 5, 25, 14, 15, 15, 9, 24, 13, 5, 28, 18, 11, 21, 15, 12, 5, 16, 5, 29, 29, 29, 3, 10, 24, 16, 16, 12, 14, 6, 22, 21, 10, 10, 2, 14, 9, 29, 29, 2, 26, 11, 6, 7, 28, 10, 3, 24, 30, 2, 23, 9, 29, 27, 19, 1, 15, 11, 5, 7, 9, 26, 28, 27, 10, 20, 23, 29, 10, 15, 30, 13, 2, 11, 5, 9, 2, 30, 27, 14, 11, 20, 19, 1, 12, 10, 8, 6, 16, 3, 25, 5, 10, 24]

var_1_1 = 1+influenza_genome[300] #we pinpoint index 300 and assign a variable to its value + 1. 
print("Value at index 300:", influenza_genome[300]) #Printing the original value at index 300, for comparison
print("Value + 1:", var_1_1) #Printing the new value at index 300, which is + 1
# Out:
# Value at index 300: 7
# Value + 1: 8

# %%
# 1.2 for the first 30 elements, if the value of the element is divisable by 3, multiply the value by 3.
print(influenza_genome[:30]) #this is to make the 2 lists easy to compare
influenza_genome_div3 = influenza_genome.copy()
for i in range(30): #we are looping through the index positions, not through the values. This sets up the index positions.
    if influenza_genome_div3[i] % 3 == 0: #this is where we test the values: IF the value at this position is divisible by 3
        influenza_genome_div3[i] = influenza_genome_div3[i] * 3 #THEN multiply the value by 3
    else: pass #otherwise, do nothing to the value
print(influenza_genome_div3[:30])
# Out:
# [19, 15, 7, 9, 12, 6, 17, 20, 29, 14, 22, 8, 15, 12, 21, 25, 11, 10, 30, 4, 6, 24, 18, 21, 28, 22, 13, 19, 4, 23]
# [19, 45, 7, 27, 36, 18, 17, 20, 29, 14, 22, 8, 45, 36, 63, 25, 11, 10, 90, 4, 18, 72, 54, 63, 28, 22, 13, 19, 4, 23]

# %%
# 1.3 for the last 30 elements, if the index value at that point is divisable by 5, replace the value with "a".
print(influenza_genome[-30:]) #this is to make the 2 lists easy to compare
influenza_genome_div5 = influenza_genome.copy()
a = "a"
for i in range(-1,-31,-1): #we are looping through the index positions, not through the values. This sets up the index positions at the end of the list.
    if influenza_genome_div5[i] % 5 == 0: #this is where we test the values; if the value at this position is divisible by 5, replace the value with "a"
        influenza_genome_div5[i] = a
    else: pass
print(influenza_genome_div5[-30:])
# Out:
# [10, 20, 23, 29, 10, 15, 30, 13, 2, 11, 5, 9, 2, 30, 27, 14, 11, 20, 19, 1, 12, 10, 8, 6, 16, 3, 25, 5, 10, 24]
# ['a', 'a', 23, 29, 'a', 'a', 'a', 13, 2, 11, 'a', 9, 2, 'a', 27, 14, 11, 'a', 19, 1, 12, 'a', 8, 6, 16, 3, 'a', 'a', 'a', 24]

# %%
# 1.4 for all elements between index 200 and 300, if the value of the element is divisable by BOTH 3 AND 5, replace the value with the 10.
print(influenza_genome[200:301]) #this is to make the 2 lists easy to compare
influenza_genome_div35 = influenza_genome.copy()
for i in range(200,301,1): #we are looping through the index positions, not through the values. This sets up the index positions.
    if influenza_genome_div35[i] % 5 == 0 and influenza_genome_div35[i] % 3 == 0: #this is where we test the values; if the value at this position is divisible by 3 and 5, replace the value with "a"
        influenza_genome_div35[i] = 10
    else: pass
print(influenza_genome_div35[200:301])
# Out:
# [21, 26, 25, 1, 24, 15, 27, 8, 23, 4, 30, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 30, 16, 30, 10, 2, 26, 26, 7, 10, 15, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 30, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 7]
# [21, 26, 25, 1, 24, 10, 27, 8, 23, 4, 10, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 10, 16, 10, 10, 2, 26, 26, 7, 10, 10, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 10, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 7]

# %%
# Problem 2 Loops within loops
# Given the array influenza_genome, write code using both for and while loops that:

####################

# 2.1 Create a for loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)
influenza_genome_21 = influenza_genome[234:238] #up to 238 because 238 will be left off
for i in influenza_genome_21: #for the index position
    print(i) #print the value
# Out:
# 4
# 7
# 12
# 24

# %%
# 2.2 Create a while loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)
i = 234 #starting at 234
while i < 238: #as long as the variable is under 238 ... 
    print(influenza_genome[i]) #print the value
    i += 1 #then move up the index by 1.
# Out:
# 4
# 7
# 12
# 24

# %%
# 2.3 Create a for loop that iterates over items index 234 through 237 and if the index is 236 print the item 7 times.
influenza_genome_23 = influenza_genome.copy()
for i in range(234,238): #up to 238 because 238 will be left off
    if i ==236:
        print((str(influenza_genome_23[i]) + " ") * 7) #first we define the exception
    else: 
        print(influenza_genome_23[i]) #then everything "else"
# Out:
# 4
# 7
# 12 12 12 12 12 12 12
# 24

# %%
# Problem 3 Functions
# You are going to implement 3 funtions that will process the influenza_genome list in various ways.

####################

# 3.1 write a function, that takes in the array as an argument, and outputs 10 values from the dataset, spaced out by indexes that are 25 apart (ie 0, 25, 50, etc)

def flu_gen_31(val): #the name of the function is flu_gen_31, and it takes an argument
    for i in range(0,250,25): #starts at 0, stops at 249, intervals of 25
        print(val[i]) #prints the values at those indexes

print(flu_gen_31(influenza_genome)) #calling the function
# Out:
# 19
# 22
# 11
# 18
# 16
# 9
# 13
# 24
# 21
# 10
# None

# %%
# 3.2 write a function that takes in the dataset as an argument and outputs 20 values from the dataset, spaced out by indexes that are y apart (ie you can decide how far apart they should be iterated as long as they dont exceed the length of the dataset)
def flu_gen_32(val32): #the name of the function is flu_gen_32, and it takes an argument
    for i in range(0,500,26): #starts at 0, stops at 499, intervals of 26
        print(val32[i]) #prints the values at those indexes

print(flu_gen_32(influenza_genome)) #calling the function
# Out:
# 19
# 13
# 30
# 27
# 10
# 14
# 7
# 26
# 23
# 4
# 27
# 29
# 9
# 23
# 15
# 19
# 28
# 9
# 28
# 16
# None

# %%
# 3.3 write a function that takes the output from the function from 3.2 as an argument, then only prints out every other item (ie there should only be 10 outputs)

def flu_gen_33(val33): #first we are going to turn the values from 3.2 into a list. Its nearly the same as 3.2, except for ... 
    list_32 = [] #this
    for i in range(0,500,26):
        list_32.append(val33[i]) #and this, the append function
    return(list_32) #we return the list, formerly empty, now filled

list_33 = flu_gen_33(influenza_genome)
print(list_33, "(for reference)") #this is the printing of the list from 3.2, just so we can compare it with the ultimate output

def flu_gen_33i(val33i): #Another function where we take every other value and put THAT into a list
    list_33 = [] #the list that will be filled
    for j in range(0,20,2): #the pattern of index positions for choosing values
        list_33.append(val33i[j]) #appending the values to the list structure
    return(list_33) #list that was empty is now filled

print(flu_gen_33i(list_33), "(the actual answer)") #printing the final answer to 3.3., which is every other value of the list of 3.2
# Out:
# [19, 13, 30, 27, 10, 14, 7, 26, 23, 4, 27, 29, 9, 23, 15, 19, 28, 9, 28, 16] (for reference)
# [19, 30, 10, 7, 23, 27, 9, 15, 28, 28] (the actual answer)

# %%
# Problem 4 Putting it all together
# Write a function that implements the code from problem 1.4, then implements the code from problem 2.3.
# The function should create a modified version of the influenza_genome list as per 1.4, then print the section described in problem 2.3. 


print(influenza_genome[200:301]) #this is to make the 2 lists easy to compare

def funct_41(influenza_genome): # 1.4 for all elements, if the value of the element is divisable by BOTH 3 AND 5, replace the value with the 10.
    influenza_genome__41_div35 = influenza_genome.copy() # make a copy so we don't overwrite original
    
    for k in range(len(influenza_genome__41_div35)): #I'm going to apply the 1.4 code to the entire length of the list, so that we retain Indexes 234-237
        if influenza_genome__41_div35[k] % 5 == 0 and influenza_genome__41_div35[k] % 3 == 0:
            influenza_genome__41_div35[k] = 10 #replaces elements divisible by 3 AND 5 with 10
    print(influenza_genome__41_div35[200:301]) # print intermediate step for comparison with original
    
    for l in range(234, 238): # 2.3, a for loop that iterates over items index 234 through 237 and if the index is 236, prints the item 7 times.
        if l == 236:
            print((str(influenza_genome__41_div35[l]) + " ") * 7) #first we define the exception
        else:
            print(influenza_genome__41_div35[l]) #then everything else

funct_41(influenza_genome) #calling the function
# Out:
# [21, 26, 25, 1, 24, 15, 27, 8, 23, 4, 30, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 30, 16, 30, 10, 2, 26, 26, 7, 10, 15, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 30, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 7]
# [21, 26, 25, 1, 24, 10, 27, 8, 23, 4, 10, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 10, 16, 10, 10, 2, 26, 26, 7, 10, 10, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 10, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 7]
# 4
# 7
# 12 12 12 12 12 12 12
# 24
